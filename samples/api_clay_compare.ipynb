# %%
from openpile.utils.py_curves import matlock_1970, modified_Matlock, api_clay

import matplotlib.pyplot as plt
params = {'sig':100, 'X':10, 'Su':100, 'eps50':0.02, 'D':4, 'kind':'cyclic', 'output_length':1e3}
plt.plot(*(api_clay(**params)), label='API RP2GEO (2014)')
plt.plot(*(matlock_1970(**params)), label='Matlock (1970)')
plt.plot(*(modified_Matlock(**params)), label='Modified Matlock (2016)')
plt.xlim(0,0.5)
plt.ylim(0,None)
plt.xlabel("y [m]")
plt.ylabel("p [kN/m]")
plt.legend()
