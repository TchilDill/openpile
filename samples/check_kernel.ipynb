# %%
from openpile.construct import Pile, SoilProfile, Layer, Model
from openpile.soilmodels import API_clay, API_sand


p = Pile.create_tubular(
    name="<pile name>", top_elevation=0, bottom_elevation=-2, diameter=0.2, wt=0.05
)

# Create a 40m deep offshore Soil Profile with a 15m water column
sp = SoilProfile(
    name="Offshore Soil Profile",
    top_elevation=0,
    water_line=15,
    layers=[
        Layer(
            name="medium dense sand",
            top=0,
            bottom=-20,
            weight=18,
            lateral_model=API_sand(phi=33, kind="cyclic"),
        ),
        Layer(
            name="firm clay",
            top=-20,
            bottom=-40,
            weight=18,
            lateral_model=API_clay(Su=[50, 70], eps50=0.015, kind="cyclic"),
        ),
    ],
)

# Create Model
M = Model(name="<model name>", pile=p, soil=sp)

# Apply bottom fixity along x-axis
M.set_support(elevation=-2,Tz=True)
# Apply axial and lateral loads
# M.set_pointload(elevation=0, Pz=100, Py=10)
M.set_pointdisplacement(elevation=-0.0, Ty=0.008, Tz=-0.01)

# Run analysis
import matplotlib.pyplot as plt

Result = M.solve()

# plot the results
Result.plot()
Result.reactions
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/xv/jzry6z9160n_589wflqc97xh0000gn/T/ipykernel_3237/1244335932.py in ?()
# ---> 33 from openpile.construct import Pile, SoilProfile, Layer, Model
#      34 from openpile.soilmodels import API_clay, API_sand
#      35
#      36
#
#     [... skipping hidden 1 frame]
#
# ~/Desktop/svc/openpile/src/openpile/construct.py in ?(self, *args, **kwargs)
#    1316                 self._Hb_spring,
#    1317                 self._Mb_spring,
#    1318                 self._tz_springs,
#    1319                 self._qz_spring,
# -> 1320             ) = create_springs()
#
# ~/Desktop/svc/openpile/src/openpile/construct.py in ?()
#    1117             tz_springs_dim = 15
#    1118             qz_spring_dim = 15
#    1119
#    1120             # Allocate array
# -> 1121             py = np.zeros(shape=(self.element_number, 2, 2, spring_dim), dtype=np.float32)
#    1122             mt = np.zeros(
#    1123                 shape=(self.element_number, 2, 2, spring_dim, spring_dim), dtype=np.float32
#    1124             )
#
# ~/Desktop/svc/openpile/src/openpile/construct.py in ?(self)
#    1108     @property
#    1109     def element_number(self) -> int:
# -> 1110         return self.element_properties.shape[0]
#
# ~/Desktop/svc/openpile/src/openpile/construct.py in ?(self)
#    1002     def element_properties(self) -> Dict[str, np.ndarray]:
#    1003         # creates element structural properties
#    1004         # merge Pile.data and coordinates
#    1005         element_properties = pd.merge_asof(
# -> 1006             left=self.element_coordinates.sort_values(by=["z_top [m]"]),
#    1007             right=self.pile.data.sort_values(by=["Elevation [m]"]),
#    1008             left_on="z_top [m]",
#    1009             right_on="Elevation [m]",
#
# ~/Desktop/svc/openpile/.venv/lib/python3.8/site-packages/pandas/util/_decorators.py in ?(*args, **kwargs)
#     327                     msg.format(arguments=_format_argument_list(allow_args)),
#     328                     FutureWarning,
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#
# ~/Desktop/svc/openpile/.venv/lib/python3.8/site-packages/pandas/core/frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6908         elif len(by):
#    6909             # len(by) == 1
#    6910
#    6911             by = by[0]
# -> 6912             k = self._get_label_or_level_values(by, axis=axis)
#    6913
#    6914             # need to rewrap column in Series to apply key function
#    6915             if key is not None:
#
# ~/Desktop/svc/openpile/.venv/lib/python3.8/site-packages/pandas/core/generic.py in ?(self, key, axis)
#    1846                 .get_level_values(key)  # type: ignore[assignment]
#    1847                 ._values
#    1848             )
#    1849         else:
# -> 1850             raise KeyError(key)
#    1851
#    1852         # Check for duplicates
#    1853         if values.ndim > 1:
#
# KeyError: 'z_top [m]'

# %%
from openpile.construct import Pile, SoilProfile, Layer, Model
from openpile.soilmodels import API_clay, API_sand


p = Pile.create_tubular(
    name="<pile name>", top_elevation=0, bottom_elevation=-2, diameter=0.2, wt=0.05
)

# Create Model
M = Model(name="<model name>", pile=p)

# Apply bottom fixity along x-axis
M.set_support(elevation=0, Ty=True)
M.set_support(elevation=-2, Tz=True, Ty=True)
# Apply axial and lateral loads
# M.set_pointload(elevation=-1, Pz=100, Py=10)
M.set_pointdisplacement(elevation=-1.0, Ty=0.008)

# Run analysis
import matplotlib.pyplot as plt

Result = M.solve()

# plot the results
Result.plot()
Result.reactions
# Out:
#    Elevation [m]  Nr [kN]     Vr [kN]  Mr [kNm]
# 0            0.0      0.0 -365.248901       0.0
# 1           -1.0      0.0  730.497802       0.0
# 2           -2.0      0.0 -365.248901       0.0
